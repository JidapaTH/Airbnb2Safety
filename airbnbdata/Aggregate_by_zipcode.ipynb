# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import re
# from sklearn.neighbors import KNeighborsClassifier

# %%
df = pd.read_csv("listings_cleaned.csv")

# %% [markdown]
# ### Step 1. group listings data by zipcode

# %%
#drop orignial categorical variables and keep binary encoded version
df = df.drop(columns=['Unnamed: 0','property_type', 'cancellation_policy', 'property_type_cleaned'])

# %%
df.isna().sum()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42584 entries, 0 to 42583
# Data columns (total 26 columns):
# host_is_superhost            42584 non-null int64
# host_total_listings_count    42584 non-null float64
# host_identity_verified       42584 non-null int64
# zipcode                      42584 non-null int64
# bathrooms                    42584 non-null float64
# bedrooms                     42584 non-null float64
# beds                         42584 non-null float64
# price                        42584 non-null float64
# availability_30              42584 non-null float64
# availability_60              42584 non-null float64
# availability_90              42584 non-null float64
# availability_365             42584 non-null float64
# reviews_per_month            42584 non-null float64
# review_scores_location       42584 non-null float64
# flexible                     42584 non-null int64
# moderate                     42584 non-null int64
# strict                       42584 non-null int64
# Apartment                    42584 non-null int64
# Bungalow                     42584 non-null int64
# Condominium                  42584 non-null int64
# Guest suite                  42584 non-null int64
# Guesthouse                   42584 non-null int64
# House                        42584 non-null int64
# Loft                         42584 non-null int64
# Other                        42584 non-null int64
# Townhouse                    42584 non-null int64
# dtypes: float64(11), int64(15)
# memory usage: 8.4 MB

# %%
#numeric variables
num = ['host_total_listings_count','bathrooms','bedrooms','beds','price',
       'availability_30','availability_60','availability_90','availability_365',
       'reviews_per_month','review_scores_location']
#binary/categorical variables
cat = list(set(list(df.columns.values))-set(num))
cat = list(set(cat) - set(['zipcode']))

# %%
#drop zipcode not in LA
df['zipcode'] = df['zipcode'].astype(int)
df = df[df['zipcode'] >= 90000]

# %%
###check number of listings for each zipcode 
# df_la.groupby('zipcode').count().reset_index()
zip_count = df['host_is_superhost'].groupby(df['zipcode']).count().reset_index()

# %%
zip_count
# Out:
#      zipcode  host_is_superhost
# 0      90001                 11
# 1      90002                  9
# 2      90003                 23
# 3      90004                520
# 4      90005                350
# 5      90006                499
# 6      90007                303
# 7      90008                127
# 8      90010                 66
# 9      90011                 39
# 10     90012                579
# 11     90013                222
# 12     90014                330
# 13     90015                461
# 14     90016                265
# 15     90017                598
# 16     90018                262
# 17     90019                696
# 18     90020                263
# 19     90021                 69
# 20     90022                 33
# 21     90023                 41
# 22     90024                612
# 23     90025                732
# 24     90026               1300
# 25     90027                776
# 26     90028               1677
# 27     90029                551
# 28     90030                  1
# 29     90031                134
# ..       ...                ...
# 262    91770                 92
# 263    91773                 27
# 264    91775                 55
# 265    91776                237
# 266    91780                178
# 267    91786                  2
# 268    91789                168
# 269    91790                 34
# 270    91791                 47
# 271    91792                 33
# 272    91801                164
# 273    91803                 86
# 274    92192                  1
# 275    92397                  1
# 276    92683                  2
# 277    92886                  1
# 278    93063                  2
# 279    93510                  8
# 280    93532                  4
# 281    93534                  6
# 282    93535                 33
# 283    93536                 56
# 284    93543                  7
# 285    93544                  2
# 286    93550                 30
# 287    93551                 39
# 288    93552                  5
# 289    93553                  1
# 290    93563                  3
# 291    93591                  2
#
# [292 rows x 2 columns]

# %%
###aggregate numeric variables by taking averages in each zipcode
df_zip = df[num].groupby(df['zipcode']).mean().reset_index()
df_zip = df_zip.set_index('zipcode')

# %%
###aggregate binary variables by counting 0/1 level's percentage in each zipcode
for i in range(len(cat)):
    ## count number of listings for each zipcode
    a = pd.DataFrame(df[cat[i]].groupby(df['zipcode']).count())
    ## count frequency of '1' levels
    a1 = pd.DataFrame(df.loc[df[cat[i]] == 1, 
                                cat[i]].groupby(df['zipcode']).count())
    ## count frequency of '0' levels
    a0 = pd.DataFrame(df.loc[df[cat[i]] == 0, 
                                cat[i]].groupby(df['zipcode']).count())
    ## creat new column names
    a1.columns = [cat[i] + '1']
    # a0.columns = [cat[i] + '0']
    ## join columns
    #m = (a.join(a0.join(a1,  how = 'outer'), how = 'inner')).fillna(0)
    m = (a.join(a1, how='outer')).fillna(0)
    ## calculate percentage = frequency/totalcount
    m.iloc[:,1] = m.iloc[:,1]/m.iloc[:,0]
    #m.iloc[:,2] = m.iloc[:,2]/m.iloc[:,0]
    m = m.iloc[:,1:2]
    ## merge with numeric variables
    df_zip = df_zip.join(m, how = 'inner')

# %%
###merged dataset for modeling
df_zip.head()
# Out:
#          host_total_listings_count  bathrooms  bedrooms      beds       price  \
# zipcode
# 90001                     7.090909   1.045455  1.000000  1.727273   69.181818
# 90002                     1.444444   1.000000  1.111111  1.444444   75.555556
# 90003                     2.391304   1.217391  1.130435  1.695652   67.652174
# 90004                     5.148077   1.391346  1.205769  1.923077  153.842308
# 90005                    10.917143   1.254286  0.971429  1.662857   87.171429
#
#          availability_30  availability_60  availability_90  availability_365  \
# zipcode
# 90001          14.909091        33.363636        51.000000        213.181818
# 90002          18.555556        40.777778        64.888889        247.555556
# 90003          14.652174        32.260870        51.695652        171.347826
# 90004          12.180769        27.986538        45.863462        147.350000
# 90005          14.545714        33.634286        53.357143        172.000000
#
#          reviews_per_month    ...     Apartment1  moderate1  Guest suite1  \
# zipcode                       ...
# 90001             1.342727    ...       0.090909   0.181818      0.000000
# 90002             2.413333    ...       0.000000   0.333333      0.000000
# 90003             2.061739    ...       0.260870   0.347826      0.000000
# 90004             1.455731    ...       0.500000   0.290385      0.013462
# 90005             2.106829    ...       0.537143   0.208571      0.000000
#
#          Bungalow1  Condominium1  Guesthouse1  flexible1  host_is_superhost1  \
# zipcode
# 90001     0.090909      0.454545     0.090909   0.272727            0.000000
# 90002     0.000000      0.000000     0.000000   0.333333            0.333333
# 90003     0.000000      0.000000     0.043478   0.173913            0.521739
# 90004     0.011538      0.013462     0.044231   0.288462            0.200000
# 90005     0.005714      0.037143     0.008571   0.254286            0.168571
#
#             Loft1   strict1
# zipcode
# 90001    0.000000  0.545455
# 90002    0.000000  0.333333
# 90003    0.000000  0.478261
# 90004    0.021154  0.421154
# 90005    0.005714  0.537143
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Step 2, add in NLP features (1st Method: word2vec)

# %%
text = pd.read_csv('textFeatures.csv')

# %%
text.head()
# Out:
#    zipcode      good      safe  peaceful     night      walk    unsafe  \
# 0    10019       NaN       NaN       NaN       NaN       NaN       NaN
# 1    10023       NaN       NaN       NaN       NaN       NaN       NaN
# 2    37738       NaN       NaN       NaN       NaN       NaN       NaN
# 3    60601       NaN       NaN       NaN       NaN       NaN       NaN
# 4    90001  0.232158  0.156485  0.083805  0.115957  0.131038  0.108312
#
#         bad  dangerous
# 0       NaN        NaN
# 1       NaN        NaN
# 2       NaN        NaN
# 3       NaN        NaN
# 4  0.179478   0.123318

# %%
text = text.set_index('zipcode')
df_txt = df_zip.join(text, on = 'zipcode', how='inner')
df_txt.head()
# Out:
#          host_total_listings_count  bathrooms  bedrooms      beds       price  \
# zipcode
# 90001                     7.090909   1.045455  1.000000  1.727273   69.181818
# 90002                     1.444444   1.000000  1.111111  1.444444   75.555556
# 90003                     2.391304   1.217391  1.130435  1.695652   67.652174
# 90004                     5.148077   1.391346  1.205769  1.923077  153.842308
# 90005                    10.917143   1.254286  0.971429  1.662857   87.171429
#
#          availability_30  availability_60  availability_90  availability_365  \
# zipcode
# 90001          14.909091        33.363636        51.000000        213.181818
# 90002          18.555556        40.777778        64.888889        247.555556
# 90003          14.652174        32.260870        51.695652        171.347826
# 90004          12.180769        27.986538        45.863462        147.350000
# 90005          14.545714        33.634286        53.357143        172.000000
#
#          reviews_per_month    ...         Loft1   strict1      good      safe  \
# zipcode                       ...
# 90001             1.342727    ...      0.000000  0.545455  0.232158  0.156485
# 90002             2.413333    ...      0.000000  0.333333  0.174719  0.129185
# 90003             2.061739    ...      0.000000  0.478261  0.199368  0.142892
# 90004             1.455731    ...      0.021154  0.421154  0.199690  0.146995
# 90005             2.106829    ...      0.005714  0.537143  0.203206  0.149090
#
#          peaceful     night      walk    unsafe       bad  dangerous
# zipcode
# 90001    0.083805  0.115957  0.131038  0.108312  0.179478   0.123318
# 90002    0.077965  0.101681  0.114704  0.079193  0.129388   0.090907
# 90003    0.089643  0.117684  0.135803  0.085547  0.143283   0.100415
# 90004    0.095235  0.113894  0.136349  0.087915  0.141293   0.102690
# 90005    0.091597  0.115445  0.135272  0.090355  0.144487   0.103797
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Step 3, add more NLP features (2nd Method: bag of words)

# %%
import pickle
with open('wordbag_final.pickle', 'rb') as f:
    wordbag = pickle.load(f)

with open('wordrank_final.pickle', 'rb') as f:
    wordrank = pickle.load(f)
    
with open('neighborhoodfeature.pickle', 'rb') as f:
    neighborf = pickle.load(f)

# %%
wordbag.head()
# Out:
#          abbot      able  absolute  absolutely  absolutely beautiful  \
# zipcode
# 90001      0.0  0.219051  0.000000    0.000000              0.000000
# 90002      0.0  0.025709  0.000000    0.011560              0.000000
# 90003      0.0  0.000000  0.000000    0.030165              0.000000
# 90004      0.0  0.048483  0.054930    0.058740              0.029149
# 90005      0.0  0.053237  0.018247    0.032387              0.009037
#
#          absolutely great  absolutely perfect  absolutely wonderful        ac  \
# zipcode
# 90001            0.000000            0.000000              0.000000  0.000000
# 90002            0.000000            0.000000              0.000000  0.000000
# 90003            0.000000            0.000000              0.000000  0.000000
# 90004            0.022464            0.043467              0.041146  0.043031
# 90005            0.023216            0.016846              0.019933  0.020846
#
#          accessible     ...      wonderful nice  wonderfully     worth  \
# zipcode                 ...
# 90001      0.000000     ...            0.000000     0.000000  0.219229
# 90002      0.000000     ...            0.000000     0.000000  0.032162
# 90003      0.098486     ...            0.000000     0.000000  0.083923
# 90004      0.053382     ...            0.008844     0.075401  0.040435
# 90005      0.047507     ...            0.006855     0.013487  0.043094
#
#             wrong      yard       yet     young  level2  sentimental  \
# zipcode
# 90001    0.000000  0.000000  0.000000  0.000000     3.0     7.450386
# 90002    0.000000  0.000000  0.061705  0.000000     3.0     2.687272
# 90003    0.000000  0.000000  0.000000  0.000000     2.0     3.168464
# 90004    0.044596  0.031295  0.056566  0.032397     1.0     5.892534
# 90005    0.025139  0.012129  0.022548  0.040805     1.0     5.285061
#
#          wordperrev
# zipcode
# 90001     31.947962
# 90002     36.027004
# 90003     32.300323
# 90004     40.439221
# 90005     35.063114
#
# [5 rows x 1003 columns]

# %%
#top_ten_idx = [i for i,x in enumerate(wordrank) if x in range(10)]
#top_ten_idx
neighborf.head()
# Out:
#              count      good      safe  peaceful     night      walk  unsafe  \
# zipcode
# 90001    80.555556  0.000000  0.111111  0.000000  0.000000  0.000000     0.0
# 90002    28.400000  0.000000  0.000000  0.000000  0.000000  0.000000     0.0
# 90003    58.266667  0.066667  0.133333  0.000000  0.000000  0.666667     0.0
# 90004    54.334311  0.026393  0.123167  0.002933  0.082111  0.246334     0.0
# 90005    54.121212  0.070707  0.101010  0.025253  0.136364  0.176768     0.0
#
#               bad  dangerous
# zipcode
# 90001    0.000000        0.0
# 90002    0.000000        0.0
# 90003    0.066667        0.0
# 90004    0.000000        0.0
# 90005    0.015152        0.0

# %%
neighborf = neighborf.reset_index(drop=False)
neighborf['len']=[len(neighborf['zipcode'][i]) for i in range(neighborf.shape[0])]
neighborf['len'].unique()
#neighborf['zipcode'] = [i[:5] for i in neighborf['zipcode']]
# Out:
# array([ 5,  6, 10, 12,  4,  7])

# %%
#Case 1: with 'CA', len=7
neighborf['zipcode']=[neighborf['zipcode'][i][2:] if neighborf['len'][i]==7 else neighborf['zipcode'][i] for i in range(neighborf.shape[0])]
#Case 2: with '-', len=10
neighborf['zipcode']=[neighborf['zipcode'][i][0:5] if re.search(r'-',neighborf['zipcode'][i]) else neighborf['zipcode'][i] for i in range(neighborf.shape[0])]
#Case 3: with 'Near' or '/n/n'
neighborf['zipcode']=[re.sub("[^0-9]", "", neighborf['zipcode'][i]) for i in range(neighborf.shape[0])]
#Case 4: len>6, take first 5 digits
neighborf['zipcode']=[neighborf['zipcode'][i][0:5] if len(neighborf['zipcode'][i])>5 else neighborf['zipcode'][i] for i in range(neighborf.shape[0])]
#Case 5: len<5 drop it
neighborf['len2']=[len(neighborf['zipcode'][i]) for i in range(neighborf.shape[0])]
neighborf = neighborf[neighborf['len2']==5].reset_index(drop=True)

#drop len & len2
neighborf = neighborf.drop(['len','len2'],axis=1)

# %%
top_ten = wordbag[wordrank[0:20]].join(wordbag.iloc[:,-1],on='zipcode',how='inner')
neighborf['zipcode'] = neighborf['zipcode'].astype(int)
neighborf = neighborf.set_index('zipcode')
top_ten = top_ten.merge(neighborf, on='zipcode', how = 'inner', suffixes=('', '_f'))
top_ten
# Out:
#             young   explore  fantastic great  fantastic    famous    fairly  \
# zipcode
# 90001    0.000000  0.000000         0.000000   0.055456  0.000000  0.000000
# 90002    0.000000  0.000000         0.090036   0.024407  0.000000  0.060558
# 90003    0.000000  0.000000         0.000000   0.031844  0.000000  0.000000
# 90004    0.032397  0.045227         0.033015   0.048585  0.056317  0.034895
# 90005    0.040805  0.050080         0.025590   0.022463  0.080027  0.056553
# 90006    0.044097  0.022762         0.030211   0.014742  0.006012  0.052831
# 90007    0.039062  0.015581         0.030330   0.036999  0.000000  0.050999
# 90008    0.000000  0.057924         0.016913   0.032095  0.033659  0.034128
# 90010    0.000000  0.064692         0.113337   0.071689  0.000000  0.012705
# 90011    0.000000  0.000000         0.000000   0.006379  0.000000  0.047480
# 90011    0.000000  0.000000         0.000000   0.006379  0.000000  0.047480
# 90012    0.037607  0.075002         0.031286   0.028271  0.024905  0.052607
# 90013    0.093596  0.099554         0.072673   0.060415  0.014463  0.043991
# 90014    0.063936  0.073447         0.056594   0.042257  0.029638  0.052088
# 90014    0.063936  0.073447         0.056594   0.042257  0.029638  0.052088
# 90015    0.038502  0.030715         0.100033   0.047066  0.013729  0.039441
# 90016    0.032248  0.042876         0.043819   0.035636  0.037373  0.016841
# 90017    0.026568  0.030026         0.054151   0.032854  0.000000  0.024281
# 90018    0.031995  0.042540         0.024843   0.037601  0.037079  0.075191
# 90019    0.044062  0.035150         0.028225   0.035938  0.056169  0.048322
# 90020    0.049410  0.022524         0.016442   0.030457  0.032721  0.044235
# 90021    0.029678  0.023676         0.034566   0.034357  0.068788  0.023249
# 90022    0.029475  0.094054         0.000000   0.024816  0.000000  0.000000
# 90023    0.043322  0.034560         0.000000   0.009119  0.000000  0.000000
# 90024    0.045267  0.028889         0.063265   0.053833  0.010492  0.017730
# 90025    0.036462  0.044601         0.059453   0.039909  0.022537  0.030467
# 90026    0.047632  0.077330         0.072995   0.055582  0.027116  0.041241
# 90027    0.023574  0.069850         0.062756   0.051037  0.039028  0.052762
# 90028    0.062352  0.070684         0.049687   0.042135  0.112192  0.032776
# 90028    0.062352  0.070684         0.049687   0.042135  0.112192  0.032776
# ...           ...       ...              ...        ...       ...       ...
# 91755    0.000000  0.000000         0.011540   0.005214  0.000000  0.031046
# 91759    0.000000  0.000000         0.000000   0.000000  0.000000  0.000000
# 91765    0.035663  0.000000         0.041536   0.037533  0.000000  0.083811
# 91766    0.029884  0.000000         0.034806   0.006290  0.000000  0.046820
# 91767    0.000000  0.000000         0.032902   0.017838  0.000000  0.000000
# 91768    0.030959  0.049395         0.036058   0.055390  0.000000  0.024252
# 90017      ...       37.499272   55.496350  0.007299  0.111922  0.000000
# 90018      ...       39.248206   60.242604  0.017751  0.112426  0.000000
# 90019      ...       37.517728   56.104513  0.016627  0.142518  0.021378
# 90020      ...       37.878123   59.189542  0.026144  0.071895  0.006536
# 90021      ...       37.841047   58.021277  0.021277  0.063830  0.000000
# 90022      ...       37.339582   54.882353  0.000000  0.117647  0.000000
# 90023      ...       37.358032   64.538462  0.000000  0.038462  0.000000
# 90024      ...       34.778220   55.526027  0.027397  0.106849  0.008219
# 90025      ...       36.483618   50.834694  0.053061  0.197959  0.008163
# 90026      ...       41.894875   71.860841  0.048544  0.038835  0.014024
# 90027      ...       41.676227   66.939335  0.029354  0.109589  0.025440
# 90028      ...       39.191881   59.932814  0.064265  0.167478  0.016553
# 90028      ...       39.191881   75.000000  0.000000  0.000000  0.000000
# ...        ...             ...         ...       ...       ...       ...
# 91755      ...       24.201450   32.283019  0.132075  0.264151  0.018868
# 91759      ...        1.000000   52.000000  0.000000  0.000000  0.000000
# 91765      ...       28.547159   29.957746  0.014085  0.098592  0.014085
# 91766      ...       25.582490   46.037037  0.000000  0.074074  0.111111
# 91767      ...       28.501839   25.727273  0.045455  0.000000  0.000000
# 91768      ...       30.952582   40.450000  0.000000  0.050000  0.050000
# 91770      ...       31.052307   24.393939  0.000000  0.090909  0.000000
# 91773      ...       35.993161   30.933333  0.000000  0.133333  0.000000
# 91775      ...       37.682936   29.190476  0.000000  0.142857  0.047619
# 91776      ...       26.377524   27.673684  0.000000  0.105263  0.000000
# 91780      ...       26.787110   18.772152  0.000000  0.063291  0.000000
# 91789      ...       23.740223   21.859649  0.000000  0.210526  0.000000
# 91790      ...       26.343488   27.923077  0.153846  0.307692  0.000000
# 91791      ...       32.161193   36.000000  0.047619  0.190476  0.095238
# 91792      ...       23.286013   10.066667  0.000000  0.000000  0.000000
# 91801      ...       28.109549   39.191919  0.010101  0.272727  0.121212
# 91803      ...       29.300914   26.428571  0.000000  0.228571  0.057143
# 92683      ...       35.616476  136.500000  0.000000  0.000000  0.000000
# 93510      ...       32.589249   37.600000  0.000000  0.000000  0.000000
# 93532      ...       33.804771   29.000000  0.000000  0.000000  0.000000
# 93534      ...       18.309050   56.000000  0.000000  0.500000  0.000000
# 93535      ...       33.797199   58.411765  0.058824  0.176471  0.176471
# 93536      ...       24.295029   31.000000  0.038462  0.230769  0.076923
# 93543      ...       37.147393   40.666667  0.000000  0.000000  0.000000
# 93544      ...       12.792043   13.000000  0.000000  0.000000  0.000000
# 93550      ...       25.619112   24.541667  0.000000  0.291667  0.041667
# 93551      ...       33.171673   26.545455  0.000000  0.318182  0.045455
# 93552      ...       23.273659   16.500000  0.000000  0.000000  0.250000
# 93563      ...       36.554681   57.500000  0.000000  0.000000  0.000000
# 93591      ...        2.000000   10.000000  0.000000  0.000000  0.000000
#
#             night      walk    unsafe       bad  dangerous
# zipcode
# 90001    0.000000  0.000000  0.000000  0.000000   0.000000
# 93535    0.000000  0.000000  0.000000  0.000000   0.000000
# 93536    0.000000  0.076923  0.000000  0.000000   0.000000
# 93543    0.000000  0.000000  0.000000  0.000000   0.000000
# 93544    0.000000  0.000000  0.000000  0.000000   0.000000
# 93550    0.041667  0.041667  0.000000  0.000000   0.000000
# 93551    0.000000  0.000000  0.000000  0.000000   0.000000
# 93552    0.250000  0.000000  0.000000  0.000000   0.000000
# 93563    0.000000  0.000000  0.000000  0.000000   0.000000
# 93591    0.000000  0.000000  0.000000  0.000000   0.000000
#
# [268 rows x 30 columns]

# %%
top_ten.columns
# Out:
# Index(['young', 'explore', 'fantastic great', 'fantastic', 'famous', 'fairly',
#        'fair', 'fabulous', 'extremely responsive', 'extremely helpful',
#        'extremely friendly', 'extremely comfortable', 'extremely clean',
#        'extremely', 'extra', 'expensive', 'even', 'exceptionally',
#        'exceptional', 'excellent great', 'wordperrev', 'count', 'good', 'safe',
#        'peaceful', 'night', 'walk', 'unsafe', 'bad', 'dangerous'],
#       dtype='object')

# %%
# df_txt = df_txt.join(top_ten, on = 'zipcode', how='inner')
# df_txt.head()
df = df_txt.merge(top_ten, on = 'zipcode', how='inner', suffixes=('', '_y'))
df.head()
# Out:
#          host_total_listings_count  bathrooms  bedrooms      beds       price  \
# zipcode
# 90001                     7.090909   1.045455  1.000000  1.727273   69.181818
# 90002                     1.444444   1.000000  1.111111  1.444444   75.555556
# 90003                     2.391304   1.217391  1.130435  1.695652   67.652174
# 90004                     5.148077   1.391346  1.205769  1.923077  153.842308
# 90005                    10.917143   1.254286  0.971429  1.662857   87.171429
#
#          availability_30  availability_60  availability_90  availability_365  \
# zipcode
# 90001          14.909091        33.363636        51.000000        213.181818
# 90002          18.555556        40.777778        64.888889        247.555556
# 90003          14.652174        32.260870        51.695652        171.347826
# 90004          12.180769        27.986538        45.863462        147.350000
# 90005          14.545714        33.634286        53.357143        172.000000
#
#          reviews_per_month     ...       wordperrev      count    good_y  \
# zipcode                        ...
# 90001             1.342727     ...        31.947962  80.555556  0.000000
# 90002             2.413333     ...        36.027004  28.400000  0.000000
# 90003             2.061739     ...        32.300323  58.266667  0.066667
# 90004             1.455731     ...        40.439221  54.334311  0.026393
# 90005             2.106829     ...        35.063114  54.121212  0.070707
#
#            safe_y  peaceful_y   night_y    walk_y  unsafe_y     bad_y  \
# zipcode
# 90001    0.111111    0.000000  0.000000  0.000000       0.0  0.000000
# 90002    0.000000    0.000000  0.000000  0.000000       0.0  0.000000
# 90003    0.133333    0.000000  0.000000  0.666667       0.0  0.066667
# 90004    0.123167    0.002933  0.082111  0.246334       0.0  0.000000
# 90005    0.101010    0.025253  0.136364  0.176768       0.0  0.015152
#
#          dangerous_y
# zipcode
# 90001            0.0
# 90002            0.0
# 90003            0.0
# 90004            0.0
# 90005            0.0
#
# [5 rows x 63 columns]

# %%
df.shape
# Out:
# (268, 63)

# %%
df.to_csv("listings_cleaned_zipcode.csv")
